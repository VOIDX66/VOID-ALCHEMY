# %% [markdown]
# <a href="https://colab.research.google.com/github/VOIDX66/VOID-ALCHEMY/blob/master/Pruebas_Automatas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

import sys

! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
sys.path.append('./Jove')
sys.path.append('./Jove/jove')

from jove.SystemImports import *
from jove.LangDef import *
from jove.Def_DFA import *
from jove.Def_md2mc import *
from jove.AnimateDFA import *

# %% [markdown]
# Ejercicio

# %%
A = md2mc('''
DFA
Iq0: a|b -> q1
q1: a|b -> Fq2
Fq2: a|b -> q3
q3: a|b -> q3
''')
dotObj_dfa(A,FuseEdges=True)

# %%
'''Probar automata'''
accepts_dfa(A,'bb')

# %%
'''Donde termina la cadena en el automata'''
run_dfa(A, 'abab')
# Out:
# 'q3'

# %%
from jove.AnimateDFA import *
AnimateDFA(A, FuseEdges=True)
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))
# Out:
# ...
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
